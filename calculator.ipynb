# %%
def calculate(num1:int, num2:int):
  if operator == '+':
    print(num1+num2)
  elif operator == '-':
    print(num1-num2)
  elif operator == '*':
    print(num1*num2)
  elif operator == '/':
    print(num1/num2)
  else:
    print("Invalid Operator.2")

# %%
num1 = int(input("Enter the first number - "))
# Out:
# Enter the first number - 30

# %%
operator = input("Enter the operator - ")
# Out:
# Enter the operator - /

# %%
num2 = int(input("Enter the second number - "))
# Out:
# Enter the second number - 2

# %%
calculate(num1, num2)
# Out:
# 15.0
